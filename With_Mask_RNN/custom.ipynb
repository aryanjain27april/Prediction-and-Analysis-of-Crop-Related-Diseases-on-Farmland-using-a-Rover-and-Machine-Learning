# %%
import os
import sys
import json
import datetime
import numpy as np
import skimage.draw
import cv2
from mrcnn.visualize import display_instances
import matplotlib.pyplot as plt

# %%
# Root directory of the project
ROOT_DIR = "D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\With_Mask_RNN"

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import model as modellib, utils

# Path to trained weights file
COCO_WEIGHTS_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Directory to save logs and model checkpoints, if not provided
# through the command line argument --logs
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")

# %%
COCO_WEIGHTS_PATH
# Out:
# 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\With_Mask_RNN\\mask_rcnn_coco.h5'

# %%
class CustomConfig(Config):
    """Configuration for training on the custom  dataset.
    Derives from the base Config class and overrides some values.
    """
    # Give the configuration a recognizable name
    NAME = "object"

    # We use a GPU with 24GB memory, which can fit 4 images.
    # Adjust down if you use a smaller GPU.
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 3  # Background + Apple_Black_Rot, Apple_Healthy, Apple_Rust, Apple_Scab, Blueberry_Healthy, Corn_Common_Rust, Corn_Gray_Leaf_Spot,Corn_Healthy, Grape_Black_Measles, Grape_Black_Rot, Grape_Healthy, Peach_Bacterial_Spot, Peach_Healthy, Pepper_Bell_Bacterial_Spot, Pepper_Bell_Healthy, Pepper_Early_Blight, Potato_Healthy, Potato_Late_Blight, Rasberry_Healthy, Soybean_Healthy,Strawberry_Leaf_Scroch,Strawberry_Healthy,Tomato_Bacterial_Spot,Tomato_Early_Blight, Tomato_Healthy,Tomato_Late_Blight,Tomato_Leaf_Spot,Tomato_Target_Spot


    # Number of training steps per epoch
    STEPS_PER_EPOCH = 10

    # Skip detections with < 90% confidence
    DETECTION_MIN_CONFIDENCE = 0.9
    


############################################################
#  Dataset
############################################################

class CustomDataset(utils.Dataset):

    def load_custom(self, dataset_dir, subset):
      
      
        # Add classes. We have only one class to add.
        # self.add_class("object", 1, "Apple_Black_Rot")
        # self.add_class("object", 2, "Apple_Healthy")
        # self.add_class("object", 3, "Apple_Rust")
        # self.add_class("object", 4, "Apple_Scab")
        # self.add_class("object", 5, "Blueberry_Healthy")
        # self.add_class("object", 6, "Corn_Common_Rust")
        # self.add_class("object", 7, "Corn_Gray_Leaf_Spot")
        # self.add_class("object", 8, "Corn_Healthy")
        # self.add_class("object", 9, "Grape_Black_Measles")
        # self.add_class("object", 10, "Grape_Black_Rot")
        # self.add_class("object", 11, "Grape_Healthy")
        # self.add_class("object", 12, "Peach_Bacterial_Spot")
        # self.add_class("object", 13, "Peach_Healthy")
        # self.add_class("object", 14, "Pepper_Bell_Bacterial_Spot")
        # self.add_class("object", 15, "Pepper_Bell_Healthy")
        # self.add_class("object", 16, "Pepper_Early_Blight")   #potato_Early_Blight
        # self.add_class("object", 17, "Potato_Healthy")
        # self.add_class("object", 18, "Potato_Late_Blight")
        # self.add_class("object", 19, "Rasberry_Healthy")
        # self.add_class("object", 20, "Soybean_Healthy")
        # self.add_class("object", 21, "Strawberry_Leaf_Scroch")
        # self.add_class("object", 22, "Strawberry_Healthy")
        # self.add_class("object", 23, "Tomato_Bacterial_Spot")
        self.add_class("object", 1, "Tomato_Early_blight_leaf")   
        self.add_class("object", 2, "Tomato_leaf")
        self.add_class("object", 3, "Tomato_mold_leaf")
        # self.add_class("object", 26, "Tomato_Late_Blight")
        # self.add_class("object", 27, "Tomato_Leaf_Spot")
        # self.add_class("object", 28, "Tomato_Target_Spot")

     
        # Train or validation dataset?
        assert subset in ["train", "test"]
        dataset_dir = os.path.join(dataset_dir, subset)
        print(dataset_dir)
        # We mostly care about the x and y coordinates of each region
        
        #annotations1 = json.load(open('D:/python3.6.8_tensorflow_1.14_env/maskrcnn_leave_disease_detection/dataset/train/train.json'))
        annotations1 = json.load(open(os.path.join(dataset_dir, 'train.json')))
        #keep the name of the json files in the both train and val folders
        
        # print(annotations1)
        annotations = list(annotations1.values())  # don't need the dict keys



        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['object']]
        
        # Add images
        for a in annotations:
            # print(a)
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. There are stores in the
            # shape_attributes (see json format above)
            polygons = [r['shape_attributes'] for r in a['object']] 
            objects = [s['region_attributes']['names'] for s in a['object']]
            print("objects:",objects)
            name_dict = {
                'Tomato_Early_blight_leaf':1,
                'Tomato_leaf':2,
                'Tomato_mold_leaf':3
            }
            #name_dict = {"Apple_Black_Rot": 1,"Apple_Healthy": 2,"Apple_Rust": 3,"Apple_Scab":4,"Blueberry_Healthy":5,"Corn_Common_Rust":6,"Corn_Gray_Leaf_Spot":7,"Corn_Healthy":8,"Grape_Black_Measles":9,"Grape_Black_Rot":10,"Grape_Healthy":11,"Peach_Bacterial_Spot":12,"Peach_Healthy":13,"Pepper_Bell_Bacterial_Spot":14,"Pepper_Bell_Healthy":15,"Pepper_Early_Blight":16,"Potato_Healthy":17,"Potato_Late_Blight":18,"Rasberry_Healthy":19,"Soybean_Healthy":20,"Strawberry_Leaf_Scroch":21,"Strawberry_Healthy":22,"Tomato_Bacterial_Spot":23,"Tomato_Early_Blight":24,"Tomato_Healthy":25,"Tomato_Late_Blight":26,"Tomato_Leaf_Spot":27,"Tomato_Target_Spot":28}
            #name_dict = {"Horse": 1,"Man": 2} #,"xyz": 3}
            # key = tuple(name_dict)
            num_ids = [name_dict[a] for a in objects]
     
            # num_ids = [int(n['Event']) for n in objects]
            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            print("numids",num_ids)
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "object",  ## for a single class just add the name here
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons,
                num_ids=num_ids
                )

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a Dog-Cat dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "object":
            return super(self.__class__, self).load_mask(image_id)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        if info["source"] != "object":
            return super(self.__class__, self).load_mask(image_id)
        num_ids = info['num_ids']
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            
            mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        # Map class names to class IDs.
        num_ids = np.array(num_ids, dtype=np.int32)
        return mask, num_ids #np.ones([mask.shape[-1]], dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "object":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)
def train(model):
    """Train the model."""
    # Training dataset.
    dataset_train = CustomDataset()
    dataset_train.load_custom("D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\With_Mask_RNN\\dataset", "train")
    
    dataset_train.prepare()

    # Validation dataset
    dataset_val = CustomDataset()
    dataset_val.load_custom("D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\With_Mask_RNN\\dataset", "test")
    dataset_val.prepare()

    # *** This training schedule is an example. Update to your needs ***
    # Since we're using a very small dataset, and starting from
    # COCO trained weights, we don't need to train too long. Also,
    # no need to train all layers, just the heads should do it.
    print("Training network heads")
    model.train(dataset_train, dataset_val,
                learning_rate=config.LEARNING_RATE,
                epochs=100,
                layers='heads')

# %%
config = CustomConfig()
model = modellib.MaskRCNN(mode="training", config=config,
                                  model_dir=DEFAULT_LOGS_DIR)

weights_path = COCO_WEIGHTS_PATH
        # Download weights file
if not os.path.exists(weights_path):
  utils.download_trained_weights(weights_path)

model.load_weights(weights_path, by_name=True, exclude=[
            "mrcnn_class_logits", "mrcnn_bbox_fc",
            "mrcnn_bbox", "mrcnn_mask"])

# %%
weights_path
# Out:
# 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\With_Mask_RNN\\mask_rcnn_coco.h5'

# %%
annotations1 = json.load(open(os.path.join('D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\With_Mask_RNN\\dataset\\train', 'train.json')))
annotations = list(annotations1.values())

# %%
annotations
# Out:
# [{'folder': 'Tomato_Early_blight_leaf',
#   'filename': '100_46341.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\100_46341.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '2160', 'height': '1440', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '909', 'ymin': '271', 'xmax': '1738', 'ymax': '1220'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '1058_0.jpeg_itok=OQkdtxgv.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\1058_0.jpeg_itok=OQkdtxgv.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '800', 'height': '600', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '4', 'ymin': '185', 'xmax': '797', 'ymax': '600'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '200', 'ymin': '15', 'xmax': '512', 'ymax': '120'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '126689-004-D622CD2F.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\126689-004-D622CD2F.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '550', 'height': '384', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '10', 'ymin': '14', 'xmax': '541', 'ymax': '376'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '12July_mwnews_3-C.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\12July_mwnews_3-C.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '330', 'height': '219', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '61', 'ymin': '15', 'xmax': '145', 'ymax': '98'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '32', 'ymin': '22', 'xmax': '87', 'ymax': '105'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '89', 'ymin': '104', 'xmax': '134', 'ymax': '181'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '137', 'ymin': '83', 'xmax': '301', 'ymax': '187'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '249', 'ymin': '23', 'xmax': '330', 'ymax': '79'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '1576389-early%20blight%20symptoms.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\1576389-early%20blight%20symptoms.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '382', 'height': '261', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '46', 'ymin': '29', 'xmax': '382', 'ymax': '247'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '20020531-early%20blight%20%20starts%20on%20lower%20leaves.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\20020531-early%20blight%20%20starts%20on%20lower%20leaves.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '498', 'height': '312', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '124', 'ymin': '105', 'xmax': '168', 'ymax': '196'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '164', 'ymin': '13', 'xmax': '215', 'ymax': '47'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '291', 'ymin': '84', 'xmax': '323', 'ymax': '145'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '217', 'ymin': '80', 'xmax': '276', 'ymax': '200'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '175', 'ymin': '73', 'xmax': '227', 'ymax': '128'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '77', 'ymin': '69', 'xmax': '108', 'ymax': '189'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '192', 'ymin': '260', 'xmax': '240', 'ymax': '291'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '34', 'ymin': '31', 'xmax': '69', 'ymax': '102'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '303', 'ymin': '174', 'xmax': '333', 'ymax': '269'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '20080526-_DSC4211.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\20080526-_DSC4211.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '465', 'height': '700', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '19', 'ymin': '396', 'xmax': '142', 'ymax': '531'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '152', 'ymin': '439', 'xmax': '239', 'ymax': '589'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '257', 'ymin': '424', 'xmax': '339', 'ymax': '551'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '112', 'ymin': '315', 'xmax': '192', 'ymax': '387'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '209', 'ymin': '193', 'xmax': '270', 'ymax': '263'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '217', 'ymin': '71', 'xmax': '312', 'ymax': '140'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '355', 'ymin': '562', 'xmax': '421', 'ymax': '678'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '49', 'ymin': '306', 'xmax': '114', 'ymax': '388'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '23', 'ymin': '204', 'xmax': '103', 'ymax': '297'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '2373320.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\2373320.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '450', 'height': '325', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '105', 'ymin': '1', 'xmax': '199', 'ymax': '91'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '330', 'ymin': '144', 'xmax': '446', 'ymax': '304'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '137', 'ymin': '100', 'xmax': '422', 'ymax': '248'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '30053_original.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\30053_original.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '500', 'height': '334', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '3', 'xmax': '499', 'ymax': '332'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '3606630.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\3606630.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '325', 'height': '216', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '15', 'ymin': '32', 'xmax': '317', 'ymax': '216'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '5086-early.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\5086-early.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '250', 'height': '301', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '80', 'ymin': '25', 'xmax': '238', 'ymax': '284'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '8%20mistakes%204.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\8%20mistakes%204.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '500', 'height': '333', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '293', 'ymin': '84', 'xmax': '425', 'ymax': '316'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '168', 'ymin': '159', 'xmax': '309', 'ymax': '333'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '86', 'ymin': '225', 'xmax': '191', 'ymax': '333'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': '8950022d45978228d5e44a35183efdb9--tomatoes-dyi.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\8950022d45978228d5e44a35183efdb9--tomatoes-dyi.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '236', 'height': '314', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '6', 'ymin': '228', 'xmax': '134', 'ymax': '301'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '118', 'xmax': '104', 'ymax': '189'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '127', 'ymin': '105', 'xmax': '236', 'ymax': '155'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '182', 'ymin': '139', 'xmax': '236', 'ymax': '218'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '111', 'ymin': '61', 'xmax': '210', 'ymax': '100'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'august-11-early-leaf-blight-single-leaf.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\august-11-early-leaf-blight-single-leaf.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '3872', 'height': '2592', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '535', 'ymin': '667', 'xmax': '3557', 'ymax': '1810'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'b54d0e40027ff5e90e8ba7e1e9abf9bd--garden-guide-garden-ideas.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\b54d0e40027ff5e90e8ba7e1e9abf9bd--garden-guide-garden-ideas.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '448', 'height': '336', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '2', 'xmax': '390', 'ymax': '324'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'BCH%20medium%20thumbnail%20for%20upload%20%2836%29.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\BCH%20medium%20thumbnail%20for%20upload%20%2836%29.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '375', 'height': '300', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '251', 'ymin': '68', 'xmax': '373', 'ymax': '299'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '126', 'ymin': '75', 'xmax': '244', 'ymax': '293'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '120', 'ymin': '16', 'xmax': '210', 'ymax': '106'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '54', 'xmax': '112', 'ymax': '151'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'blog_early_blight_628.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\blog_early_blight_628.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '432', 'height': '652', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '78', 'ymin': '103', 'xmax': '257', 'ymax': '181'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '295', 'ymin': '95', 'xmax': '432', 'ymax': '257'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '95', 'ymin': '204', 'xmax': '270', 'ymax': '553'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '225', 'ymin': '306', 'xmax': '371', 'ymax': '559'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'confused-bacterial-canker-early-blight-zoom.JPG.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\confused-bacterial-canker-early-blight-zoom.JPG.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '419', 'height': '284', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '252', 'ymin': '90', 'xmax': '296', 'ymax': '198'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '45', 'ymin': '161', 'xmax': '96', 'ymax': '279'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '105', 'ymin': '151', 'xmax': '151', 'ymax': '245'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '163', 'ymin': '100', 'xmax': '226', 'ymax': '190'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '27', 'ymin': '17', 'xmax': '125', 'ymax': '76'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Diseased-Tomato-Plant.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Diseased-Tomato-Plant.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '680', 'height': '510', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '78', 'ymin': '67', 'xmax': '364', 'ymax': '365'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '432', 'ymin': '14', 'xmax': '503', 'ymax': '131'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '519', 'ymin': '14', 'xmax': '629', 'ymax': '346'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'droppedImage_3-1.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\droppedImage_3-1.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '800', 'height': '602', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '170', 'ymin': '319', 'xmax': '282', 'ymax': '585'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '153', 'ymin': '249', 'xmax': '207', 'ymax': '354'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '105', 'ymin': '94', 'xmax': '162', 'ymax': '220'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '167', 'ymin': '72', 'xmax': '246', 'ymax': '173'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '564', 'ymin': '175', 'xmax': '695', 'ymax': '388'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '464', 'ymin': '200', 'xmax': '571', 'ymax': '372'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '490', 'ymin': '3', 'xmax': '590', 'ymax': '157'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '323', 'ymin': '48', 'xmax': '437', 'ymax': '234'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '309', 'ymin': '1', 'xmax': '436', 'ymax': '123'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '339', 'ymin': '445', 'xmax': '403', 'ymax': '523'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'dscn3168.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\dscn3168.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '2592', 'height': '1944', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '890', 'ymin': '1274', 'xmax': '1152', 'ymax': '1736'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '1243',
#      'ymin': '1276',
#      'xmax': '1571',
#      'ymax': '1684'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '2043',
#      'ymin': '1419',
#      'xmax': '2374',
#      'ymax': '1934'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '274', 'ymin': '634', 'xmax': '502', 'ymax': '1200'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '1450', 'ymin': '531', 'xmax': '1726', 'ymax': '865'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '1993',
#      'ymin': '1098',
#      'xmax': '2398',
#      'ymax': '1469'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '614', 'ymin': '1065', 'xmax': '919', 'ymax': '1281'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '776', 'ymin': '348', 'xmax': '952', 'ymax': '726'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '417', 'ymin': '65', 'xmax': '676', 'ymax': '631'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'ealryblight.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\ealryblight.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '600', 'height': '800', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '19', 'ymin': '63', 'xmax': '564', 'ymax': '671'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early%20blight%20%283%29.jpg_itok=UMYWI0xr.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early%20blight%20%283%29.jpg_itok=UMYWI0xr.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '567', 'height': '393', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '1', 'xmax': '565', 'ymax': '392'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early%20blight%20%284%29.jpg_itok=gfK5C193.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early%20blight%20%284%29.jpg_itok=gfK5C193.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '567', 'height': '393', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '3', 'ymin': '28', 'xmax': '567', 'ymax': '391'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Early+Blight+-+Tomatoes.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Early+Blight+-+Tomatoes.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '350', 'height': '263', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '30', 'ymin': '23', 'xmax': '332', 'ymax': '260'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight-2x.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight-2x.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '450', 'height': '575', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '55', 'xmax': '449', 'ymax': '524'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Early-blight-660x440.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Early-blight-660x440.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '660', 'height': '440', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '281', 'ymin': '18', 'xmax': '459', 'ymax': '320'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '101', 'ymin': '120', 'xmax': '324', 'ymax': '440'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '229', 'xmax': '109', 'ymax': '440'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '42', 'ymin': '1', 'xmax': '241', 'ymax': '79'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight-closeup-sm.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight-closeup-sm.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '454', 'height': '291', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '251', 'ymin': '81', 'xmax': '380', 'ymax': '291'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '71', 'ymin': '41', 'xmax': '268', 'ymax': '291'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '53', 'xmax': '93', 'ymax': '223'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight-in-high-tunnel-tomatoes-19tm74h.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight-in-high-tunnel-tomatoes-19tm74h.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '2978', 'height': '2091', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '488', 'ymin': '39', 'xmax': '2972', 'ymax': '2061'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight-in-tomatoes.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight-in-tomatoes.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '600', 'height': '900', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '27', 'ymin': '259', 'xmax': '568', 'ymax': '855'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight-of-tomato-tomato-1.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight-of-tomato-tomato-1.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '300', 'height': '400', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '62', 'ymin': '74', 'xmax': '299', 'ymax': '281'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '1', 'xmax': '152', 'ymax': '124'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight-or-target-spot-alternaria-solani-lesions-on-a-tomato-BH3TH0.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight-or-target-spot-alternaria-solani-lesions-on-a-tomato-BH3TH0.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '1083', 'height': '1390', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '114', 'ymin': '131', 'xmax': '947', 'ymax': '1265'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight-or-target-spot-alternaria-solani-lesions-on-a-tomato-BY9J8R.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight-or-target-spot-alternaria-solani-lesions-on-a-tomato-BY9J8R.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '1300', 'height': '1359', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '4', 'ymin': '42', 'xmax': '1300', 'ymax': '1270'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight-pp-labeled_orig.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight-pp-labeled_orig.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '499', 'height': '332', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '22', 'ymin': '115', 'xmax': '148', 'ymax': '261'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '147', 'ymin': '42', 'xmax': '482', 'ymax': '332'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Early-blight.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Early-blight.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '598', 'height': '332', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '5', 'ymin': '179', 'xmax': '196', 'ymax': '288'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '134', 'ymin': '25', 'xmax': '388', 'ymax': '141'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-blight1.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-blight1.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '300', 'height': '343', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '73', 'xmax': '142', 'ymax': '286'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '145', 'ymin': '13', 'xmax': '297', 'ymax': '343'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Early-bligh_t.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Early-bligh_t.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '810', 'height': '450', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '176', 'ymin': '32', 'xmax': '530', 'ymax': '197'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '11', 'ymin': '237', 'xmax': '266', 'ymax': '387'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early-tomato-blight.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early-tomato-blight.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '150', 'height': '150', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '70', 'ymin': '7', 'xmax': '149', 'ymax': '138'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '77', 'xmax': '69', 'ymax': '145'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '1', 'xmax': '70', 'ymax': '28'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '32', 'xmax': '17', 'ymax': '73'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'earlyblight.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\earlyblight.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '298', 'height': '246', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '1', 'xmax': '156', 'ymax': '245'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'earlyblightpotato.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\earlyblightpotato.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '465', 'height': '350', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '164', 'ymin': '18', 'xmax': '422', 'ymax': '350'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'earlyblightresize.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\earlyblightresize.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '320', 'height': '240', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '40', 'xmax': '320', 'ymax': '219'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'earlyblighttomato.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\earlyblighttomato.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '328', 'height': '477', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '39', 'ymin': '57', 'xmax': '311', 'ymax': '455'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Early_blight_1.jpg_1376579808.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Early_blight_1.jpg_1376579808.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '800', 'height': '511', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '329', 'ymin': '338', 'xmax': '500', 'ymax': '511'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '101', 'ymin': '237', 'xmax': '254', 'ymax': '496'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '224', 'ymin': '227', 'xmax': '446', 'ymax': '440'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '308', 'ymin': '76', 'xmax': '441', 'ymax': '276'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '103', 'ymin': '33', 'xmax': '323', 'ymax': '303'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Early_Blight_of_Tomato1687.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Early_Blight_of_Tomato1687.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '800', 'height': '600', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '68', 'ymin': '292', 'xmax': '385', 'ymax': '600'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '132', 'ymin': '2', 'xmax': '800', 'ymax': '506'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early_blight_spots_l.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early_blight_spots_l.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '400', 'height': '300', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '47', 'xmax': '400', 'ymax': '300'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'early_blight_tomato.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\early_blight_tomato.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '1008', 'height': '672', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '444', 'ymin': '358', 'xmax': '515', 'ymax': '504'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '536', 'ymin': '205', 'xmax': '692', 'ymax': '316'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '348', 'ymin': '241', 'xmax': '437', 'ymax': '332'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'ebleafb.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\ebleafb.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '600', 'height': '400', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '102', 'xmax': '573', 'ymax': '398'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'eblight5.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\eblight5.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '564', 'height': '377', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '198', 'ymin': '78', 'xmax': '364', 'ymax': '377'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '106', 'ymin': '36', 'xmax': '238', 'ymax': '119'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '30', 'ymin': '172', 'xmax': '96', 'ymax': '269'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '230', 'xmax': '91', 'ymax': '370'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'EBTomato.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\EBTomato.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '300', 'height': '450', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '5', 'ymin': '12', 'xmax': '238', 'ymax': '450'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'FS547-2-big.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\FS547-2-big.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '640', 'height': '433', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '7', 'xmax': '620', 'ymax': '395'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'gn201410308259997ar-jpg.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\gn201410308259997ar-jpg.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '804', 'height': '604', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '123', 'ymin': '178', 'xmax': '560', 'ymax': '353'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '662', 'ymin': '449', 'xmax': '748', 'ymax': '604'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'halleck_tomato_earlyblight__inline-half.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\halleck_tomato_earlyblight__inline-half.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '303', 'height': '296', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '37', 'ymin': '27', 'xmax': '238', 'ymax': '261'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'IMG_0591.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\IMG_0591.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '1920', 'height': '1440', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '423', 'xmax': '1911', 'ymax': '1430'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'IMG_2436w.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\IMG_2436w.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '800', 'height': '600', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '134', 'ymin': '144', 'xmax': '607', 'ymax': '600'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '164', 'ymin': '34', 'xmax': '443', 'ymax': '204'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'MPC105550.jpg.rendition.largest.ss.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\MPC105550.jpg.rendition.largest.ss.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '300', 'height': '300', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '92', 'ymin': '64', 'xmax': '140', 'ymax': '188'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '51', 'ymin': '68', 'xmax': '128', 'ymax': '148'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '150', 'ymin': '72', 'xmax': '192', 'ymax': '170'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Original_e-blight.JPG.rend.hgtvcom.966.725.jpeg.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Original_e-blight.JPG.rend.hgtvcom.966.725.jpeg.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '966', 'height': '725', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '109', 'ymin': '1', 'xmax': '709', 'ymax': '725'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'p1020083cs.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\p1020083cs.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '800', 'height': '597', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '282', 'ymin': '1', 'xmax': '666', 'ymax': '339'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '204', 'xmax': '452', 'ymax': '596'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '462', 'ymin': '289', 'xmax': '800', 'ymax': '594'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'p1020084s.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\p1020084s.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '800', 'height': '600', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '277', 'ymin': '66', 'xmax': '526', 'ymax': '255'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '129', 'ymin': '336', 'xmax': '306', 'ymax': '503'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '273', 'ymin': '388', 'xmax': '528', 'ymax': '597'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '515', 'ymin': '392', 'xmax': '783', 'ymax': '594'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '18', 'ymin': '191', 'xmax': '154', 'ymax': '268'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '517', 'ymin': '158', 'xmax': '675', 'ymax': '307'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '614', 'ymin': '86', 'xmax': '800', 'ymax': '364'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'spotonleaf1.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\spotonleaf1.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '300', 'height': '225', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '45', 'ymin': '92', 'xmax': '126', 'ymax': '209'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '37', 'ymin': '37', 'xmax': '98', 'ymax': '89'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '191', 'ymin': '4', 'xmax': '252', 'ymax': '110'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '128', 'ymin': '123', 'xmax': '216', 'ymax': '225'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '98', 'ymin': '1', 'xmax': '169', 'ymax': '80'}},
#    {'name': 'Healthy',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '227', 'ymin': '118', 'xmax': '300', 'ymax': '225'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Tomato%20early%20blight%20target%20like%20leaf%20spot.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Tomato%20early%20blight%20target%20like%20leaf%20spot.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '286', 'height': '209', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '15', 'ymin': '1', 'xmax': '235', 'ymax': '209'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Tomato-Alternaria-Early-Blight.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Tomato-Alternaria-Early-Blight.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '3872', 'height': '2592', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '32', 'ymin': '1110', 'xmax': '2157', 'ymax': '2592'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1746',
#      'ymin': '1175',
#      'xmax': '3789',
#      'ymax': '2592'}},
#    {'name': 'Early_Blight',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '1', 'ymin': '15', 'xmax': '1578', 'ymax': '1021'}}]},
#  {'folder': 'Tomato_Early_blight_leaf',
#   'filename': 'Tomato-blight-large.jpg',
#   'path': 'D:\\Programs\\8th_Sem_Proj\\train\\Tomato_Early_blight_leaf\\Tomato-blight-large.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '600', 'height': '538', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'Early_Blight',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '108', 'ymin': '6', 'xmax': '528', 'ymax': '446'}}},
#  {'folder': 'Tomato_Early_blight_leaf',
# ...
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '314', 'ymin': '346', 'xmax': '458', 'ymax': '536'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '53', 'ymin': '109', 'xmax': '372', 'ymax': '305'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '283', 'ymin': '31', 'xmax': '635', 'ymax': '200'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '371', 'ymin': '190', 'xmax': '537', 'ymax': '280'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '542', 'ymin': '223', 'xmax': '636', 'ymax': '294'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tdisease7.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tdisease7.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '750', 'height': '559', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '73', 'ymin': '308', 'xmax': '386', 'ymax': '520'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '299', 'ymin': '359', 'xmax': '638', 'ymax': '559'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '240', 'ymin': '68', 'xmax': '439', 'ymax': '239'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '373', 'ymin': '1', 'xmax': '558', 'ymax': '216'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '530', 'ymin': '78', 'xmax': '724', 'ymax': '239'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '33', 'ymin': '177', 'xmax': '289', 'ymax': '328'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'Tomato%20greenhouse%20leaf%20edema%20and%20distortion2F.JPG.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\Tomato%20greenhouse%20leaf%20edema%20and%20distortion2F.JPG.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '1024', 'height': '768', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '60', 'ymin': '262', 'xmax': '843', 'ymax': '659'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'Tomato+leaf+mold.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\Tomato+leaf+mold.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '1600', 'height': '1200', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '551', 'ymin': '661', 'xmax': '1366', 'ymax': '1046'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '29', 'ymin': '756', 'xmax': '306', 'ymax': '1200'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '789', 'ymin': '78', 'xmax': '1255', 'ymax': '379'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '1341',
#      'ymin': '256',
#      'xmax': '1566',
#      'ymax': '525'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato-gray-leaf-spot.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato-gray-leaf-spot.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '150', 'height': '150', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '1',
#    'difficult': '0',
#    'bndbox': {'xmin': '1', 'ymin': '12', 'xmax': '150', 'ymax': '147'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato-leaf-2.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato-leaf-2.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '2048', 'height': '1536', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '63', 'ymin': '22', 'xmax': '1979', 'ymax': '1198'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato-leaf-mold-2.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato-leaf-mold-2.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '150', 'height': '100', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '27', 'ymin': '9', 'xmax': '127', 'ymax': '86'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato-leaf-mold-infection-on-a-leaf-top-and-underside-picture-id81781575_s=612x612.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato-leaf-mold-infection-on-a-leaf-top-and-underside-picture-id81781575_s=612x612.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '612', 'height': '569', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '51', 'ymin': '119', 'xmax': '258', 'ymax': '565'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '166', 'ymin': '12', 'xmax': '274', 'ymax': '122'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '243', 'ymin': '128', 'xmax': '591', 'ymax': '346'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato-leaf-mold.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato-leaf-mold.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '150', 'height': '150', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '24', 'ymin': '21', 'xmax': '149', 'ymax': '122'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '600', 'height': '800', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '34', 'ymin': '299', 'xmax': '254', 'ymax': '381'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '293', 'ymin': '340', 'xmax': '598', 'ymax': '395'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'TomatoLeafMold1-50QUALITY-16lgkq6.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\TomatoLeafMold1-50QUALITY-16lgkq6.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '667', 'height': '500', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '25', 'ymin': '102', 'xmax': '582', 'ymax': '426'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'TomatoLeafMold2-50QUALITY-1b89zfs.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\TomatoLeafMold2-50QUALITY-1b89zfs.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '667', 'height': '500', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '22', 'ymin': '107', 'xmax': '646', 'ymax': '385'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato_fulvia.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato_fulvia.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '450', 'height': '304', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '28', 'ymin': '47', 'xmax': '407', 'ymax': '220'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato_fulvia2.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato_fulvia2.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '640', 'height': '405', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '149', 'ymin': '125', 'xmax': '336', 'ymax': '235'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '421', 'ymin': '170', 'xmax': '632', 'ymax': '291'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato_leaf-mold_01_zoom.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato_leaf-mold_01_zoom.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '900', 'height': '675', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '257', 'ymin': '16', 'xmax': '489', 'ymax': '342'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '499', 'ymin': '59', 'xmax': '725', 'ymax': '145'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '726', 'ymin': '64', 'xmax': '826', 'ymax': '188'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '4', 'ymin': '361', 'xmax': '261', 'ymax': '544'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '161', 'ymin': '417', 'xmax': '407', 'ymax': '639'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '432', 'ymin': '437', 'xmax': '620', 'ymax': '593'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '6', 'ymin': '228', 'xmax': '304', 'ymax': '402'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '731', 'ymin': '293', 'xmax': '807', 'ymax': '390'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato_leaf-mold_02_zoom.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato_leaf-mold_02_zoom.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '900', 'height': '675', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '217', 'ymin': '112', 'xmax': '752', 'ymax': '550'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '757', 'ymin': '127', 'xmax': '874', 'ymax': '336'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato_leaf-mold_03_zoom.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato_leaf-mold_03_zoom.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '900', 'height': '675', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '15', 'ymin': '97', 'xmax': '897', 'ymax': '573'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato_leaf-mold_04_zoom.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato_leaf-mold_04_zoom.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '900', 'height': '675', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '582', 'ymin': '350', 'xmax': '834', 'ymax': '475'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '527', 'ymin': '289', 'xmax': '735', 'ymax': '379'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '512', 'ymin': '409', 'xmax': '682', 'ymax': '559'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '355', 'ymin': '364', 'xmax': '483', 'ymax': '662'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '408', 'ymin': '61', 'xmax': '589', 'ymax': '295'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '70', 'ymin': '301', 'xmax': '281', 'ymax': '536'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '35', 'ymin': '532', 'xmax': '304', 'ymax': '651'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '209', 'ymin': '104', 'xmax': '355', 'ymax': '195'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '337', 'ymin': '110', 'xmax': '438', 'ymax': '277'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato_Leaf-roll-physiological-7059-SLoewen_thm.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato_Leaf-roll-physiological-7059-SLoewen_thm.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '115', 'height': '85', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '2', 'ymin': '35', 'xmax': '32', 'ymax': '68'}}},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'tomato_plants_1_original.JPG_1407178095.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\tomato_plants_1_original.JPG_1407178095.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '1632', 'height': '1224', 'depth': '3'},
#   'segmented': '0',
#   'object': [{'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '824', 'ymin': '518', 'xmax': '1273', 'ymax': '751'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '553', 'ymin': '756', 'xmax': '715', 'ymax': '910'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '0',
#     'difficult': '0',
#     'bndbox': {'xmin': '921', 'ymin': '740', 'xmax': '1264', 'ymax': '861'}},
#    {'name': 'mold_leaf',
#     'pose': 'Unspecified',
#     'truncated': '1',
#     'difficult': '0',
#     'bndbox': {'xmin': '697', 'ymin': '1', 'xmax': '993', 'ymax': '343'}}]},
#  {'folder': 'Tomato_mold_leaf',
#   'filename': 'top-leaf-mold-Fulva-fulvea-WN.jpg',
#   'path': 'D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\train\\Tomato_mold_leaf\\top-leaf-mold-Fulva-fulvea-WN.jpg',
#   'source': {'database': 'Unknown'},
#   'size': {'width': '800', 'height': '525', 'depth': '3'},
#   'segmented': '0',
#   'object': {'name': 'mold_leaf',
#    'pose': 'Unspecified',
#    'truncated': '0',
#    'difficult': '0',
#    'bndbox': {'xmin': '183', 'ymin': '124', 'xmax': '750', 'ymax': '395'}}}]

# %%
annotations = [a for a in annotations if a['object']]

# %%
train(model)
# Out:
# D:\8th_Sem_Proj\Dataset\8th_Sem_Proj\With_Mask_RNN\dataset\train
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\8th_Sem_Proj\Dataset\8th_Sem_Proj\With_Mask_RNN\custom.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000005?line=0'>1</a> train(model)
#
# d:\8th_Sem_Proj\Dataset\8th_Sem_Proj\With_Mask_RNN\custom.ipynb Cell 4' in train(model)
#     <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=161'>162</a> # Training dataset.
#     <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=162'>163</a> dataset_train = CustomDataset()
# --> <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=163'>164</a> dataset_train.load_custom("D:\\8th_Sem_Proj\\Dataset\\8th_Sem_Proj\\With_Mask_RNN\\dataset", "train")
#     <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=165'>166</a> dataset_train.prepare()
#     <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=167'>168</a> # Validation dataset
#
# d:\8th_Sem_Proj\Dataset\8th_Sem_Proj\With_Mask_RNN\custom.ipynb Cell 4' in CustomDataset.load_custom(self, dataset_dir, subset)
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=75'>76</a> annotations = list(annotations1.values())  # don't need the dict keys
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=79'>80</a> # The VIA tool saves images in the JSON even if they don't have any
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=80'>81</a> # annotations. Skip unannotated images.
# ---> <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=81'>82</a> annotations = [a for a in annotations if a['regions']]
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=83'>84</a> # Add images
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=84'>85</a> for a in annotations:
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=85'>86</a>     # print(a)
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=86'>87</a>     # Get the x, y coordinaets of points of the polygons that make up
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=87'>88</a>     # the outline of each object instance. There are stores in the
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=88'>89</a>     # shape_attributes (see json format above)
#
# d:\8th_Sem_Proj\Dataset\8th_Sem_Proj\With_Mask_RNN\custom.ipynb Cell 4' in <listcomp>(.0)
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=75'>76</a> annotations = list(annotations1.values())  # don't need the dict keys
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=79'>80</a> # The VIA tool saves images in the JSON even if they don't have any
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=80'>81</a> # annotations. Skip unannotated images.
# ---> <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=81'>82</a> annotations = [a for a in annotations if a['regions']]
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=83'>84</a> # Add images
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=84'>85</a> for a in annotations:
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=85'>86</a>     # print(a)
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=86'>87</a>     # Get the x, y coordinaets of points of the polygons that make up
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=87'>88</a>     # the outline of each object instance. There are stores in the
#      <a href='vscode-notebook-cell:/d%3A/8th_Sem_Proj/Dataset/8th_Sem_Proj/With_Mask_RNN/custom.ipynb#ch0000000?line=88'>89</a>     # shape_attributes (see json format above)
#
# KeyError: 'regions'
